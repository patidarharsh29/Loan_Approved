# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('loan_approval_dataset.csv')
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.shape
# Out:
# (4269, 13)

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.str.strip()

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df = df.drop('loan_id',axis=1)

# %%
df
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='loan_status', data=df)
plt.title("Loan Status Count")
plt.show()

# %%
numeric_cols = ['income_annum', 'loan_amount', 'loan_term', 'cibil_score',
                'residential_assets_value', 'commercial_assets_value',
                'luxury_assets_value', 'bank_asset_value']
plt.figure(figsize=(15,10))
for i, col in enumerate(numeric_cols):
    plt.subplot(3,3,i+1)
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
numeric_cols = ['income_annum', 'loan_amount', 'loan_term', 'cibil_score',
                'residential_assets_value', 'commercial_assets_value',
                'luxury_assets_value', 'bank_asset_value']
plt.figure(figsize=(15,10))
for i, col in enumerate(numeric_cols):
    plt.subplot(3,3,i+1)
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
categorical_cols = ['education', 'self_employed', 'no_of_dependents']

# 1 row, 3 columns ka subplot create karo
fig, axes = plt.subplots(1, 3, figsize=(15,5))  # 1 row, 3 plots

for i, col in enumerate(categorical_cols):
    sns.countplot(x=col, data=df, ax=axes[i])
    axes[i].set_title(f"{col} Count")
    # value counts print karna bhi ho toh
    print(f"\nValue Counts for {col}:")
    print(df[col].value_counts())

plt.tight_layout()
plt.show()
# Out:
# Value Counts for education:
# education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64
#
# Value Counts for self_employed:
# self_employed
# Yes    2150
# No     2119
# Name: count, dtype: int64
#
# Value Counts for no_of_dependents:
# no_of_dependents
# 4    752
# 3    727
# 0    712
# 2    708
# 1    697
# 5    673
# Name: count, dtype: int64

# %%
numeric_cols = ['income_annum', 'loan_amount', 'loan_term', 'cibil_score',
                'residential_assets_value', 'commercial_assets_value',
                'luxury_assets_value', 'bank_asset_value']
plt.figure(figsize=(15,10))
for i, col in enumerate(numeric_cols):
    plt.subplot(3,3,i+1)
    sns.boxplot(x='loan_status', y=col, data=df)
    plt.title(f"{col} vs Loan Status")
plt.tight_layout()
plt.show()

# %%
df_encoded = pd.get_dummies(df,drop_first=True)

# %%
df_encoded
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# ...

# %%
df_encoded = df_encoded.astype(int)

# %%
df_encoded
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report,confusion_matrix

# %%
X  = df_encoded.drop('loan_status_ Rejected', axis=1)
y = df_encoded['loan_status_ Rejected']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
modelS = {
    "Logistic Regression" : LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Byeas" : GaussianNB(),
    "Decision Tree" : DecisionTreeClassifier(),
    "SVM" : SVC(),
    "Random Forest" : RandomForestClassifier(n_estimators=100, random_state=42)
}

# %%
result = []

# %%
for name, model in modelS.items():
    if name in ["Logistic Regression", "KNN", "SVM"]:
        model.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    result.append({
        'model' : name,
        'Accuracy' : round(acc,4),
        'f1 score' : round(f1,4)
    })
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(4,3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.8993, 'f1 score': 0.8626},
#  {'model': 'KNN', 'Accuracy': 0.8923, 'f1 score': 0.8571},
#  {'model': 'Naive Byeas', 'Accuracy': 0.7717, 'f1 score': 0.5806},
#  {'model': 'Decision Tree', 'Accuracy': 0.9778, 'f1 score': 0.97},
#  {'model': 'SVM', 'Accuracy': 0.9262, 'f1 score': 0.9026},
#  {'model': 'Random Forest', 'Accuracy': 0.9754, 'f1 score': 0.9666},
#  {'model': 'Logistic Regression', 'Accuracy': 0.8993, 'f1 score': 0.8626},
#  {'model': 'KNN', 'Accuracy': 0.8923, 'f1 score': 0.8571},
#  {'model': 'Naive Byeas', 'Accuracy': 0.7717, 'f1 score': 0.5806},
#  {'model': 'Decision Tree', 'Accuracy': 0.9766, 'f1 score': 0.9683},
#  {'model': 'SVM', 'Accuracy': 0.9262, 'f1 score': 0.9026},
#  {'model': 'Random Forest', 'Accuracy': 0.9754, 'f1 score': 0.9666}]

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.8993, 'f1 score': 0.8626},
#  {'model': 'KNN', 'Accuracy': 0.8923, 'f1 score': 0.8571},
#  {'model': 'Naive Byeas', 'Accuracy': 0.7717, 'f1 score': 0.5806},
#  {'model': 'Decision Tree', 'Accuracy': 0.9778, 'f1 score': 0.97},
#  {'model': 'SVM', 'Accuracy': 0.9262, 'f1 score': 0.9026},
#  {'model': 'Random Forest', 'Accuracy': 0.9754, 'f1 score': 0.9666},
#  {'model': 'Logistic Regression', 'Accuracy': 0.8993, 'f1 score': 0.8626},
#  {'model': 'KNN', 'Accuracy': 0.8923, 'f1 score': 0.8571},
#  {'model': 'Naive Byeas', 'Accuracy': 0.7717, 'f1 score': 0.5806},
#  {'model': 'Decision Tree', 'Accuracy': 0.9766, 'f1 score': 0.9683},
#  {'model': 'SVM', 'Accuracy': 0.9262, 'f1 score': 0.9026},
#  {'model': 'Random Forest', 'Accuracy': 0.9754, 'f1 score': 0.9666}]

# %%
import joblib
joblib.dump(modelS['Decision Tree'],'Model.pkl')
joblib.dump(X.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']

# %%
X.columns
# Out:
# Index(['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term',
#        'cibil_score', 'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'education_ Not Graduate',
#        'self_employed_ Yes'],
#       dtype='object')

# %%
import pickle

with open("columns.pkl", "rb") as f:
    cols = pickle.load(f)

print(cols)
# Out:
# ['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value', 'education_ Not Graduate', 'self_employed_ Yes']

# %%
# Q1 = df_clean['bank_asset_value'].quantile(0.25)
# Q3 = df_clean['bank_asset_value'].quantile(0.75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
# print(f"Q1 (25%): {Q1}")
# print(f"Q3 (75%): {Q3}")
# print(f"IQR: {IQR}")
# print(f"Lower Bound: {lower_bound}")
# print(f"Upper Bound: {upper_bound}")
# df_clean = df[(df['bank_asset_value'] >= lower_bound) & 
#               (df['bank_asset_value'] <= upper_bound)]
# print("Original dataset shape:", df.shape)
# print("New dataset shape after removing outliers:", df_clean.shape)

# %%
# Q1 = df_clean['commercial_assets_value'].quantile(0.25)
# Q3 = df_clean['commercial_assets_value'].quantile(0.75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
# print(f"Q1 (25%): {Q1}")
# print(f"Q3 (75%): {Q3}")
# print(f"IQR: {IQR}")
# print(f"Lower Bound: {lower_bound}")
# print(f"Upper Bound: {upper_bound}")
# df_clean = df_clean[(df_clean['commercial_assets_value'] >= lower_bound) & 
#               (df_clean['commercial_assets_value'] <= upper_bound)]
# print("Original dataset shape:", df.shape)
# print("New dataset shape after removing outliers:", df_clean.shape)
# Out:
# Q1 (25%): 1300000.0
# Q3 (75%): 7600000.0
# IQR: 6300000.0
# Lower Bound: -8150000.0
# Upper Bound: 17050000.0
# Original dataset shape: (4269, 13)
# New dataset shape after removing outliers: (4217, 13)

# %%
# Q1 = df_clean['residential_assets_value'].quantile(0.25)
# Q3 = df_clean['residential_assets_value'].quantile(0.75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
# print(f"Q1 (25%): {Q1}")
# print(f"Q3 (75%): {Q3}")
# print(f"IQR: {IQR}")
# print(f"Lower Bound: {lower_bound}")
# print(f"Upper Bound: {upper_bound}")
# df_clean = df_clean[(df_clean['residential_assets_value'] >= lower_bound) & 
#               (df_clean['residential_assets_value'] <= upper_bound)]
# print("Original dataset shape:", df.shape)
# print("New dataset shape after removing outliers:", df_clean.shape)
# Out:
# Q1 (25%): 2100000.0
# Q3 (75%): 11200000.0
# IQR: 9100000.0
# Lower Bound: -11550000.0
# Upper Bound: 24850000.0
# Original dataset shape: (4269, 13)
# New dataset shape after removing outliers: (4167, 13)

# %%
#df_clean = df.copy()

# %%
#le = LabelEncoder()
#df_clean["self_employed"]=le.fit_transform(df_clean["self_employed"])
#df_clean["loan_status"]=le.fit_transform(df_clean["loan_status"])

#df_clean.drop(columns=["loan_id"],inplace=True)

# %%
#df_clean = pd.get_dummies(df_clean, columns=['education'], drop_first=True)

# %%
#df_clean= df_clean.astype(int)

# %%
#X = df_clean.drop(columns=["loan_status"]) #Independent
#y = df_clean["loan_status"] #Dependent

# %%
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#from sklearn.ensemble import RandomForestClassifier
#rf_model = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
#rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
# Predictions
#y_pred = rf_model.predict(X_test)

# %%
#from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
#print("Accuracy:", accuracy_score(y_test, y_pred))
#print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
#print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.978708303761533
#
# Confusion Matrix:
#  [[878   9]
#  [ 21 501]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       887
#            1       0.98      0.96      0.97       522
#
#     accuracy                           0.98      1409
#    macro avg       0.98      0.97      0.98      1409
# weighted avg       0.98      0.98      0.98      1409

# %%
#print(df_clean['loan_status'].value_counts())
# Out:
# loan_status
# 0    2596
# 1    1571
# Name: count, dtype: int64

# %%
#import pickle

# %%
#with open('Model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# Save the scaler
#with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
#import os
#print(os.getcwd())
# Out:
# C:\Users\ny266

# %%
df_clean
# Out:
#       no_of_dependents  self_employed  income_annum  loan_amount  loan_term  \
# 1                    0              1       4100000     12200000          8
# 2                    3              0       9100000     29700000         20
# 3                    3              0       8200000     30700000          8
# 4                    5              1       9800000     24200000         20
# 5                    0              1       4800000     13500000         10
# ...                ...            ...           ...          ...        ...
# 4264                 5              1       1000000      2300000         12
# 4265                 0              1       3300000     11300000         20
# 4266                 2              0       6500000     23900000         18
# 4267                 1              0       4100000     12800000          8
# 4268                 1              0       9200000     29700000         10
#
# ...

# %%
df
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 0           1                 2       Graduate            No       9600000
# 1           2                 0   Not Graduate           Yes       4100000
# 2           3                 3       Graduate            No       9100000
# 3           4                 3       Graduate            No       8200000
# 4           5                 5   Not Graduate           Yes       9800000
# ...       ...               ...            ...           ...           ...
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
# ...

# %%
print(df['loan_status'].value_counts())
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64
